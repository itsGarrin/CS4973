# %%
from openai import OpenAI
import os
from datasets import load_dataset
from langchain.text_splitter import RecursiveCharacterTextSplitter
import math
import json
import re
import tqdm
import pandas as pd


client = OpenAI(base_url=os.getenv("URL"), api_key=os.getenv("KEY"))

# %%
khoury_dataset = load_dataset("nickeldime/khouryprogram")

# %%
# load from markdown file (ends in .md)

with open("template-for-qa.md", "r") as f:
    prompt = f.read()

all_questions_answers = []

for i in tqdm.tqdm(range(len(khoury_dataset["train"]))):
    khoury_page = khoury_dataset["train"][i]["content"]
    url = khoury_dataset["train"][i]["url"]

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=512, chunk_overlap=50, length_function=len
    )

    chunks = text_splitter.split_text(khoury_page)

    # split chunks into a list of lists, with each list of size 10 (or less), but make them all similar size
    chunk_list = [chunks[i:i + 8] for i in range(0, len(chunks), 8)]

    total_questions = 0
    
    questions_needed = []
    for chunk in chunk_list:
        percentage = len(chunk) / len(chunks)

        num_questions = math.ceil(percentage * 20)
        questions_needed.append(num_questions)

    
    answers = []


    for j in range(len(chunk_list)):
        conversation = [{ "role": "assistant", 
                "content": "".join(chunk_list[j])}, 
                {"role": "user", 
                "content": f'''Generate ${questions_needed[j]} detailed question-answer pairs about the content above that a prospective student might ask. Focus on key concepts, techniques, and best practices discussed in the content. Ensure the answers are comprehensive and informative.
                Return the results in JSON format, with each pair containing a "question" field and an "answer" field. Enclose the entire JSON output in triple backticks with the "json" language specifier.
                Example format:
                ```json
                [{{"question": "How are you?",
                 "answer": "I am doing well!"}}, 
                 ...]
                 ```'''}]
        
        try:
            resp = client.chat.completions.create(
                messages = conversation,
                model = "meta-llama/Meta-Llama-3.1-8B-Instruct",
                temperature=0)
            answers.append(resp.choices[0].message.content)
        except Exception as e:
            print("Error with", url, e)
            with open(f"output/{i}.md", "w") as f:
                f.write("Mistake here \n\n")
                f.write(str(e))
                f.write("\n\n")
            continue

    answers_for_this_page = []

    # print(answers)
    # Extract question-answer pairs from the json text
    for answer in answers:
        json_match = re.search(r'```json\s*([\s\S]*?)\s*```', answer)

        try:
        
            if json_match:
                json_content = json_match.group(1)
                python_list = json.loads(json_content)
            else:
                print("No JSON found in answer", answer)
                with open(f"output/{i}.md", "w") as f:
                    f.write("Mistake here \n\n")
                    f.write(answer)
                    f.write("\n\n")
        except Exception as e:
            print("Error with", url, e)
            with open(f"output/{i}.md", "w") as f:
                f.write("Mistake here \n\n")
                f.write(str(e))
                f.write("\n\n")
        
        for qa_pair in python_list:
            answers_for_this_page.append(qa_pair)

    all_questions_answers.append({"url": url, "qa_pairs": answers_for_this_page})

    # questions = []
    # answers = []

    # save to file
    with open(f"output/{i}.md", "w") as f:
        f.write(f"# {url}\n\n")
        for qa_pair in answers_for_this_page:
            # questions.append(qa_pair['question'])
            # answers.append(qa_pair['answer'])
            f.write(f"Question: {qa_pair['question']}\nAnswer: {qa_pair['answer']}\n\n")
    print("Success with", url, len(answers_for_this_page))

    # data = pd.DataFrame({"questions": questions, "answers": answers})
    # data.to_parquet(f"output_parquet/{i}.parquet")

all_questions_answers

# %%
total = 0
questions = []
answers = []

for page in all_questions_answers:
    qa_pairs = page["qa_pairs"]

    total += len(qa_pairs)

    for qa_pair in qa_pairs:
        questions.append(qa_pair['question'])
        answers.append(qa_pair['answer'])

    print("URL:", page["url"], "Num QA pairs:", len(qa_pairs))

print(total)
print(total / 98)

# convert to parquet
data = pd.DataFrame({"questions": questions, "answers": answers})
data.to_parquet("output.parquet")
# Out:
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-science/ Num QA pairs: 159
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-science/bscs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-science/bacs/ Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-science/computing-law-bs/ Num QA pairs: 10
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-science/interdisciplinary-studies-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-science/minor/ Num QA pairs: 10
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/cybersecurity/ Num QA pairs: 27
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/cybersecurity/cybersecurity-bs/ Num QA pairs: 19
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/data-science/ Num QA pairs: 28
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/data-science/data-science-bs/ Num QA pairs: 28
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/data-science/data-science-minor/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-behavioral-neuroscience-bs/ Num QA pairs: 27
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-biology-bs/ Num QA pairs: 30
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-business-administration-bs/ Num QA pairs: 24
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-cognitive-psychology-bs/ Num QA pairs: 24
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-communication-studies-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-criminal-justice-bs/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-design-bs/ Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/economics-bs/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-english-bs/ Num QA pairs: 20
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-environmental-sustainability-sciences-bs/ Num QA pairs: 25
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-game-development-bs/ Num QA pairs: 27
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-history-bs/ Num QA pairs: 25
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-journalism-bs/ Num QA pairs: 23
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-linguistics-bs/ Num QA pairs: 10
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-mathematics-bs/ Num QA pairs: 18
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-media-arts-bs/ Num QA pairs: 24
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-music-bs/ Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-concentration-music-composition-technology-bs/ Num QA pairs: 23
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-philosophy-bs/ Num QA pairs: 14
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-physics-bs/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-political-science-bs/ Num QA pairs: 20
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-politics-philosophy-economics-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-sociology-bs/ Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-speech-language-pathology-audiology-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-theatre-bs/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/cybersecurity-business-administration-bs/ Num QA pairs: 23
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/cybersecurity-criminal-justice-bs/ Num QA pairs: 23
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/cybersecurity-economics-bs/ Num QA pairs: 18
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-behavioral-neuroscience-bs/ Num QA pairs: 24
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-biochemistry-bs/ Num QA pairs: 28
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-biology-bs/ Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-business-administration-bs/ Num QA pairs: 25
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-chemistry-bs/ Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-criminal-justice-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-design-bs/ Num QA pairs: 29
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-ecology-evolutionary-biology-bs/ Num QA pairs: 18
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-economics-bs/ Num QA pairs: 28
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-environmental-sustainability-sciences-bs/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-health-science-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-international-affairs-bs/ Num QA pairs: 23
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-journalism-bs/ Num QA pairs: 25
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-linguistics-bs/ Num QA pairs: 12
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-mathematics-bs/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-philosophy-bs/ Num QA pairs: 25
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-physics-bs/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-psychology-bs/ Num QA pairs: 25
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-public-health-bs/ Num QA pairs: 23
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-speech-language-pathology-audiology-bs/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-music-bs Num QA pairs: 26
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/computer-science-speech-language-pathology-audiology-bs Num QA pairs: 19
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/computer-information-science-combined-majors/data-science-speech-language-pathology-audiology-bs Num QA pairs: 16
# URL: https://catalog.northeastern.edu/undergraduate/computer-information-science/accelerated-bachelor-graduate-degree-programs/ Num QA pairs: 14
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/ Num QA pairs: 20
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/ Num QA pairs: 4
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/academic-probation-and-dismissal/ Num QA pairs: 15
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/absenteeism/ Num QA pairs: 14
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/campus-transfer/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/certificates/ Num QA pairs: 14
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/incomplete-grades/ Num QA pairs: 14
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/pass-fail/ Num QA pairs: 15
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/reentry-to-program/ Num QA pairs: 15
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/repeating-courses/ Num QA pairs: 15
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/academic-policies-procedures/transferring-to-ccis/ Num QA pairs: 11
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/ Num QA pairs: 161
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/computer-science-phd/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/artificial-intelligence-ms/ Num QA pairs: 10
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/complex-network-analysis-ms/ Num QA pairs: 20
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/data-science-ms/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/data-science-ms-align/ Num QA pairs: 22
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/robotics-ms/ Num QA pairs: 14
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/statistics-ms/ Num QA pairs: 21
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/statistics-ms-connect/ Num QA pairs: 20
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/computer-science-mscs/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/computer-science-mscs-align/ Num QA pairs: 13
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/cloud-software-development-graduate-certificate/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/computer-science-graduate-certificate/ Num QA pairs: 15
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/data-analytics-graduate-certificate/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/computer-science/inclusive-computer-science-education-graduate-certificate/ Num QA pairs: 15
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/cybersecurity/ Num QA pairs: 31
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/cybersecurity/cybersecurity-bachelors-degree-entrance-phd/ Num QA pairs: 24
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/cybersecurity/cybersecurity-ms/ Num QA pairs: 6
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/cybersecurity/cybersecurity-ms-align/ Num QA pairs: 20
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/cybersecurity/cybersecurity-graduate-certificate/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/interdisciplinary/ Num QA pairs: 16
# URL: https://catalog.northeastern.edu/graduate/computer-information-science/interdisciplinary/personal-health-informatics-phd/ Num QA pairs: 22
# 2251
# 22.96938775510204

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 get_questions_answers_for_page(0)
#
# NameError: name 'get_questions_answers_for_page' is not defined
